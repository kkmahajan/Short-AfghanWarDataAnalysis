# %%
import pandas as pd

# %%
afghan = pd.read_csv('F:/Desktop/Kaustubh/DataScience/RadicalTechnologies/Pig/afghanWarDataAnalysis/afghan.csv')

# %%
afghan
# Out:
#                       Type                Category      Region Attack on
# 0             Enemy Action             Direct Fire     RC EAST     ENEMY
# 1          Friendly Action     Cache Found/Cleared     RC EAST    FRIEND
# 2         Non-Combat Event              Propaganda    RC SOUTH   NEUTRAL
# 3             Enemy Action             Direct Fire     RC EAST     ENEMY
# 4          Friendly Action     Cache Found/Cleared     RC EAST    FRIEND
# 5      Suspicious Incident            Surveillance  RC CAPITAL     ENEMY
# 6      Suspicious Incident            Surveillance  RC CAPITAL     ENEMY
# 7             Enemy Action           Indirect Fire     RC EAST     ENEMY
# 8             Enemy Action           Indirect Fire     RC EAST     ENEMY
# 9          Friendly Action     Cache Found/Cleared    RC SOUTH    FRIEND
# 10         Friendly Action     Cache Found/Cleared     RC EAST    FRIEND
# 11         Friendly Action     Cache Found/Cleared     RC EAST    FRIEND
# ...

# %%
afghan.Type
# Out:
# 0               Enemy Action
# 1            Friendly Action
# 2           Non-Combat Event
# 3               Enemy Action
# 4            Friendly Action
# 5        Suspicious Incident
# 6        Suspicious Incident
# 7               Enemy Action
# 8               Enemy Action
# 9            Friendly Action
# 10           Friendly Action
# 11           Friendly Action
# 12              Enemy Action
# 13          Explosive Hazard
# 14           Friendly Action
# 15          Explosive Hazard
# 16          Explosive Hazard
# 17              Enemy Action
# 18          Explosive Hazard
# 19          Explosive Hazard
# 20              Enemy Action
# 21          Explosive Hazard
# 22          Explosive Hazard
# 23          Explosive Hazard
# 24           Friendly Action
# 25              Enemy Action
# 26              Enemy Action
# 27              Enemy Action
# 28              Enemy Action
# 29          Explosive Hazard
#                 ...
# 76881           Enemy Action
# ...

# %%
explosive = afghan[afghan['Type']=='Explosive Hazard']

# %%
explosive.loc[explosive.Category == 'IED Explosion']
# Out:
#                    Type       Category      Region Attack on
# 13     Explosive Hazard  IED Explosion    RC SOUTH     ENEMY
# 16     Explosive Hazard  IED Explosion    RC SOUTH     ENEMY
# 19     Explosive Hazard  IED Explosion    RC SOUTH     ENEMY
# 115    Explosive Hazard  IED Explosion     RC EAST     ENEMY
# 122    Explosive Hazard  IED Explosion     RC EAST     ENEMY
# 174    Explosive Hazard  IED Explosion    RC SOUTH     ENEMY
# 186    Explosive Hazard  IED Explosion     RC EAST     ENEMY
# 191    Explosive Hazard  IED Explosion     RC EAST     ENEMY
# 192    Explosive Hazard  IED Explosion     RC EAST     ENEMY
# 193    Explosive Hazard  IED Explosion     RC EAST     ENEMY
# 199    Explosive Hazard  IED Explosion     RC EAST     ENEMY
# 219    Explosive Hazard  IED Explosion    RC SOUTH     ENEMY
# 244    Explosive Hazard  IED Explosion     RC EAST     ENEMY
# 259    Explosive Hazard  IED Explosion    RC SOUTH     ENEMY
# ...
